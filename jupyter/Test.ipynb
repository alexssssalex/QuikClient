# %%
from src.quikclient import QuikClient
import time

# %%
c= QuikClient()

# %%
['CROSSRATE', 'SMAL', 'INDX', 'TQBR', 'CETS', 'SPBFUT', 'RTSIDX', 'SPBOPT']
# Out:
# ['CROSSRATE', 'SMAL', 'INDX', 'TQBR', 'CETS', 'SPBFUT', 'RTSIDX', 'SPBOPT']

# %%
# c.get_class_info('TQBR')
df = c.get_candle_data('TQBR', 'GAZP', 'INTERVAL_M1')

# %%
df.columns.isin(['D', 'H', 'L', 'O', 'C', 'V'])
# Out:
# array([ True,  True,  True,  True,  True,  True])

# %%
# Out:
# ['GBP', 'EUR', 'GBX', 'SUR', 'USD', 'HKD', 'RUR', 'BGN']

# %%
for cls in c.get_classes_list():
    print(cls)
    codes = c.get_class_codes(cls)
    print('--', codes)
    for cod in codes:
        print('---',cod)
        print('---', c.get_class_code_info(cls, cod))
        # time.sleep(0.5)
# Out:
# CROSSRATE
# -- ['GBP', 'EUR', 'GBX', 'SUR', 'USD', 'HKD', 'RUR', 'BGN']
# --- GBP
# --- {'isin_code': '', 'sell_leg_seccode': '', 'trade_currency': 'GBP', 'second_currcode': '', 'face_value': 0.0, 'nextcoupon': 0, 'qty_scale': 2, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GBP', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'Кросс-курсы валют', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'British pound', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'British pound', 'min_price_step': 0.0001, 'buy_leg_seccode': '', 'code': 'GBP', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CROSSRATE'}
# --- EUR
# --- {'isin_code': '', 'sell_leg_seccode': '', 'trade_currency': 'EUR', 'second_currcode': '', 'face_value': 0.0, 'nextcoupon': 0, 'qty_scale': 2, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'EUR', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'Кросс-курсы валют', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Euro', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Euro', 'min_price_step': 0.0001, 'buy_leg_seccode': '', 'code': 'EUR', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CROSSRATE'}
# --- GBX
# --- {'isin_code': '', 'sell_leg_seccode': '', 'trade_currency': 'GBX', 'second_currcode': '', 'face_value': 0.0, 'nextcoupon': 0, 'qty_scale': 2, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GBX', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'Кросс-курсы валют', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 6, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'British pence', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'British pence', 'min_price_step': 1e-06, 'buy_leg_seccode': '', 'code': 'GBX', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CROSSRATE'}
# --- SUR
# --- {'isin_code': '', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.0, 'nextcoupon': 0, 'qty_scale': 2, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'SUR', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'Кросс-курсы валют', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 7, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Russian ruble', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Russian ruble', 'min_price_step': 1e-07, 'buy_leg_seccode': '', 'code': 'SUR', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CROSSRATE'}
# --- USD
# --- {'isin_code': '', 'sell_leg_seccode': '', 'trade_currency': 'USD', 'second_currcode': '', 'face_value': 0.0, 'nextcoupon': 0, 'qty_scale': 2, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'USD', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'Кросс-курсы валют', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'USA Dollar', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'USA Dollar', 'min_price_step': 0.0001, 'buy_leg_seccode': '', 'code': 'USD', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CROSSRATE'}
# --- HKD
# --- {'isin_code': '', 'sell_leg_seccode': '', 'trade_currency': 'HKD', 'second_currcode': '', 'face_value': 0.0, 'nextcoupon': 0, 'qty_scale': 2, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'HKD', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'Кросс-курсы валют', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Hong Kong Dollar', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Hong Kong Dollar', 'min_price_step': 0.0001, 'buy_leg_seccode': '', 'code': 'HKD', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CROSSRATE'}
# --- RUR
# --- {'isin_code': '', 'sell_leg_seccode': '', 'trade_currency': 'RUR', 'second_currcode': '', 'face_value': 0.0, 'nextcoupon': 0, 'qty_scale': 2, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'RUR', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'Кросс-курсы валют', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'RUR', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'RUR', 'min_price_step': 0.01, 'buy_leg_seccode': '', 'code': 'RUR', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CROSSRATE'}
# --- BGN
# --- {'isin_code': '', 'sell_leg_seccode': '', 'trade_currency': 'BGN', 'second_currcode': '', 'face_value': 0.0, 'nextcoupon': 0, 'qty_scale': 2, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'BGN', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'Кросс-курсы валют', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'BGN', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'BGN', 'min_price_step': 0.0001, 'buy_leg_seccode': '', 'code': 'BGN', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CROSSRATE'}
# SMAL
# -- ['ABRD', 'ACKO', 'AFKS', 'AFLT', 'ALBK', 'ALRS', 'AMEZ', 'APTK', 'AQUA', 'ARSA', 'ASSB', 'BISV', 'BISVP', 'BLNG', 'BSPB', 'CBOM', 'CHEP', 'CHGZ', 'CNTL', 'CNTLP', 'DASB', 'DIOD', 'DSKY', 'DVEC', 'EELT', 'ENRU', 'FEES', 'FESH', 'GAZA', 'GAZAP', 'GAZC', 'GAZP', 'GAZS', 'GAZT', 'GRNT', 'GTLC', 'GTRK', 'GTSS', 'HIMC', 'HIMCP', 'HYDR', 'IRAO', 'IRGZ', 'IRKT', 'ISKJ', 'JNOS', 'JNOSP', 'KAZT', 'KAZTP', 'KBSB', 'KBTK', 'KCHE', 'KCHEP', 'KGKC', 'KGKCP', 'KLSB', 'KMAZ', 'KMTZ', 'KRKO', 'KRKOP', 'KROT', 'KROTP', 'KRSB', 'KRSBP', 'KSGR', 'KTSB', 'KTSBP', 'KUBE', 'KUNF', 'KUZB', 'KZMS', 'KZOS', 'KZOSP', 'LIFE', 'LPSB', 'LSNG', 'LSNGP', 'LVHK', 'MAGE', 'MAGEP', 'MAGN', 'MERF', 'MFGS', 'MFGSP', 'MISB', 'MISBP', 'MOBB', 'MOEX', 'MORI', 'MRKC', 'MRKK', 'MRKP', 'MRKS', 'MRKU', 'MRKV', 'MRKY', 'MRKZ', 'MRSB', 'MSNG', 'MSRS', 'MSST', 'MSTT', 'MTLRP', 'MTSS', 'MVID', 'NAUK', 'NFAZ', 'NKHP', 'NKNC', 'NKNCP', 'NKSH', 'NLMK', 'NMTP', 'NSVZ', 'ODVA', 'OGKB', 'PIKK', 'PMSB', 'PMSBP', 'POGR', 'PRFN', 'RASP', 'RAVN', 'RBCM', 'RDRB', 'RGSS', 'RLMN', 'RLMNP', 'ROLO', 'ROSB', 'ROSN', 'ROST', 'RSTI', 'RSTIP', 'RTKM', 'RTKMP', 'RTSB', 'RTSBP', 'RU', 'A', 'ERGA', 'RU', 'A', 'JNUW', 'RU', 'A', 'JPGC', 'RU', 'A', 'JPLG', 'RU', 'A', 'JPZL', 'RU', 'A', 'JR', 'RU', 'A', 'JR', 'A', 'RU', 'A', 'JR', 'C', 'RU', 'A', 'JT', 'G', 'RU', 'A', 'JX', 'H', 'RUAL', 'RUGR', 'RUSI', 'RUSP', 'RZSB', 'SAGO', 'SAGOP', 'SARE', 'SAREP', 'SBER', 'SBERP', 'SELG', 'SELGP', 'SFIN', 'SIBG', 'SIBN', 'SLEN', 'SNGS', 'SNGSP', 'STSB', 'STSBP', 'SVAV', 'TASB', 'TASBP', 'TGKA', 'TGKB', 'TGKBP', 'TGKD', 'TGKDP', 'TGKN', 'TORS', 'TORSP', 'TRFM', 'TRMK', 'TTLK', 'TUCH', 'TUZA', 'UNAC', 'UPRO', 'URKA', 'USBN', 'UTAR', 'VGSB', 'VGSBP', 'VJGZP', 'VLHZ', 'VRSB', 'VRSBP', 'VTBR', 'VZRZP', 'WTCM', 'WTCMP', 'YAKG', 'YKEN', 'YKENP', 'YRSB', 'YRSBP', 'ZVEZ']
# --- ABRD
# --- {'isin_code': 'RU000A0JS5T7', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'ABRD', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 1, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-02-12500-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Абрау-Дюрсо ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'АбрауДюрсо', 'min_price_step': 0.5, 'buy_leg_seccode': '', 'code': 'ABRD', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- ACKO
# --- {'isin_code': 'RU000A0JXS91', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'ACKO', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-52065-Z', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'АСКО-СТРАХОВАНИЕ ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'АСКО ао', 'min_price_step': 0.02, 'buy_leg_seccode': '', 'code': 'ACKO', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- AFKS
# --- {'isin_code': 'RU000A0DQZE3', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.09, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'AFKS', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 3, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-05-01669-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'АФК "Система" ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Система ао', 'min_price_step': 0.001, 'buy_leg_seccode': '', 'code': 'AFKS', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- AFLT
# --- {'isin_code': 'RU0009062285', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'AFLT', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-00010-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Аэрофлот-росс.авиалин(ПАО)ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Аэрофлот', 'min_price_step': 0.02, 'buy_leg_seccode': '', 'code': 'AFLT', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- ALBK
# --- {'isin_code': 'RU000A0JS2M9', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 10.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'ALBK', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 1, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '10400435B', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Бест Эффортс Банк ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'БестЭфБ ао', 'min_price_step': 0.5, 'buy_leg_seccode': '', 'code': 'ALBK', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- ALRS
# --- {'isin_code': 'RU0007252813', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.5, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'ALRS', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-03-40046-N', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'АЛРОСА ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'АЛРОСА ао', 'min_price_step': 0.01, 'buy_leg_seccode': '', 'code': 'ALRS', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- AMEZ
# --- {'isin_code': 'RU000A0B88G6', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'AMEZ', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 2, 'first_curr_qty_scale': 0, 'scale': 3, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-03-45219-D', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Ашинский метзавод ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'АшинскийМЗ', 'min_price_step': 0.005, 'buy_leg_seccode': '', 'code': 'AMEZ', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- APTK
# --- {'isin_code': 'RU0008081765', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.64, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'APTK', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 2, 'first_curr_qty_scale': 0, 'scale': 3, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-07335-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ПАО "Аптечная сеть 36,6" ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Аптеки36и6', 'min_price_step': 0.002, 'buy_leg_seccode': '', 'code': 'APTK', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- AQUA
# --- {'isin_code': 'RU000A0JQTS3', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 100.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'AQUA', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 2, 'first_curr_qty_scale': 0, 'scale': 1, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-04461-D', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Русская Аквакультура ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'РусАква ао', 'min_price_step': 0.5, 'buy_leg_seccode': '', 'code': 'AQUA', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- ARSA
# --- {'isin_code': 'RU000A0JP0Q7', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'ARSA', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-03163-D', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'УК Арсагера ПАО-ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Арсагера', 'min_price_step': 0.01, 'buy_leg_seccode': '', 'code': 'ARSA', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- ASSB
# --- {'isin_code': 'RU000A0D8MM8', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.007, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'ASSB', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-55064-E', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"Астраханская ЭСК" ПАО', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'АстрЭнСб', 'min_price_step': 0.0005, 'buy_leg_seccode': '', 'code': 'ASSB', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- BISV
# --- {'isin_code': 'RU0009059216', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'BISV', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-00011-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Башинформсвязь(ПАО) ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'БашИнСв ао', 'min_price_step': 0.05, 'buy_leg_seccode': '', 'code': 'BISV', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- BISVP
# --- {'isin_code': 'RU0009100176', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'BISVP', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '2-01-00011-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Башинформсвязь(ПАО) ап', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'БашИнСв ап', 'min_price_step': 0.01, 'buy_leg_seccode': '', 'code': 'BISVP', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- BLNG
# --- {'isin_code': 'RU000A0J2QG8', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.01, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'BLNG', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 3, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-06-10167-F', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Белон ОАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Белон ао', 'min_price_step': 0.002, 'buy_leg_seccode': '', 'code': 'BLNG', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- BSPB
# --- {'isin_code': 'RU0009100945', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'BSPB', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '10300436B', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ПАО "Банк "Санкт-Петербург" ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'БСП ао', 'min_price_step': 0.01, 'buy_leg_seccode': '', 'code': 'BSPB', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- CBOM
# --- {'isin_code': 'RU000A0JUG31', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'CBOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 3, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '10101978B', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"МКБ" ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'МКБ ао', 'min_price_step': 0.001, 'buy_leg_seccode': '', 'code': 'CBOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- CHEP
# --- {'isin_code': 'RU0009066807', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'CHEP', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 1, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-00182-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"ЧТПЗ" ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ЧТПЗ ао', 'min_price_step': 0.5, 'buy_leg_seccode': '', 'code': 'CHEP', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- CHGZ
# --- {'isin_code': 'RU0009082291', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.1, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'CHGZ', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 1, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-00185-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'РН-Западная Сибирь ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'РН-ЗапСиб', 'min_price_step': 0.2, 'buy_leg_seccode': '', 'code': 'CHGZ', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- CNTL
# --- {'isin_code': 'RU0007665147', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'CNTL', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-03-00327-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"Центральный Телеграф" ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Телеграф', 'min_price_step': 0.02, 'buy_leg_seccode': '', 'code': 'CNTL', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- CNTLP
# --- {'isin_code': 'RU0007665139', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'CNTLP', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '2-03-00327-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"Центральный Телеграф" ПАО ап', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'Телеграф-п', 'min_price_step': 0.02, 'buy_leg_seccode': '', 'code': 'CNTLP', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- DASB
# --- {'isin_code': 'RU000A0F63G0', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.003, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'DASB', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-55094-E', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ао Дагестанская энергосб.комп.', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ДагСб ао', 'min_price_step': 0.0001, 'buy_leg_seccode': '', 'code': 'DASB', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- DIOD
# --- {'isin_code': 'RU000A0JQWC1', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.01, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'DIOD', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-03-06923-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'Завод ДИОД ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ЗаводДИОД', 'min_price_step': 0.01, 'buy_leg_seccode': '', 'code': 'DIOD', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- DSKY
# --- {'isin_code': 'RU000A0JSQ90', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.0004, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'DSKY', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-02-00844-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ПАО Детский мир', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ДетскийМир', 'min_price_step': 0.02, 'buy_leg_seccode': '', 'code': 'DSKY', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- DVEC
# --- {'isin_code': 'RU000A0JP2W1', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'DVEC', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 3, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-55275-E', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"ДЭК" ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ДЭК ао', 'min_price_step': 0.001, 'buy_leg_seccode': '', 'code': 'DVEC', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- EELT
# --- {'isin_code': 'RU000A0JWW54', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'EELT', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-83993-H', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"ЕвропЭлектротехника" ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ЕвроЭлтех', 'min_price_step': 0.02, 'buy_leg_seccode': '', 'code': 'EELT', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- ENRU
# --- {'isin_code': 'RU000A0F5UN3', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'ENRU', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-50077-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"Энел Россия" ПАО', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ЭнелРос ао', 'min_price_step': 0.0005, 'buy_leg_seccode': '', 'code': 'ENRU', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- FEES
# --- {'isin_code': 'RU000A0JPNN9', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.5, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'FEES', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 5, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-65018-D', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"ФСК ЕЭС" ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ФСК ЕЭС ао', 'min_price_step': 2e-05, 'buy_leg_seccode': '', 'code': 'FEES', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- FESH
# --- {'isin_code': 'RU0008992318', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'FESH', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-03-00032-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ДВ морское пароходство ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ДВМП ао', 'min_price_step': 0.01, 'buy_leg_seccode': '', 'code': 'FESH', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GAZA
# --- {'isin_code': 'RU0009034268', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GAZA', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 1, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-00029-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ГАЗ ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ГАЗ ао', 'min_price_step': 0.5, 'buy_leg_seccode': '', 'code': 'GAZA', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GAZAP
# --- {'isin_code': 'RU000A0ZYHF5', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GAZAP', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 1, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '2-02-00029-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ГАЗ ПАО ап', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ГАЗ ап', 'min_price_step': 0.5, 'buy_leg_seccode': '', 'code': 'GAZAP', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GAZC
# --- {'isin_code': 'RU000A0JQG86', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 10.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GAZC', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 0, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-09870-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ГАЗКОН (ПАО) ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ГАЗКОН-ао', 'min_price_step': 1.0, 'buy_leg_seccode': '', 'code': 'GAZC', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GAZP
# --- {'isin_code': 'RU0007661625', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 5.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GAZP', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 1, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-02-00028-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': '"Газпром" (ПАО) ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ГАЗПРОМ ао', 'min_price_step': 0.01, 'buy_leg_seccode': '', 'code': 'GAZP', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GAZS
# --- {'isin_code': 'RU000A0JQG78', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 10.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GAZS', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 0, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-09871-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ГАЗ-сервис (ПАО) ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ГАЗ-сервис', 'min_price_step': 1.0, 'buy_leg_seccode': '', 'code': 'GAZS', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GAZT
# --- {'isin_code': 'RU000A0JS199', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 100.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GAZT', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 1, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-12996-A', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ГАЗ-Тек ПАО ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ГАЗ-Тек ао', 'min_price_step': 0.5, 'buy_leg_seccode': '', 'code': 'GAZT', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GRNT
# --- {'isin_code': 'RU000A0JV532', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GRNT', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-05280-D', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ГородскиеИнновацТехнологии ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ГИТ ао', 'min_price_step': 0.0005, 'buy_leg_seccode': '', 'code': 'GRNT', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GTLC
# --- {'isin_code': 'RU000A0JTN19', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 0.2, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GTLC', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-03-22061-H', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ПАО "ДжиТиЭл" ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ПАОДжиТиЭл', 'min_price_step': 0.0001, 'buy_leg_seccode': '', 'code': 'GTLC', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GTRK
# --- {'isin_code': 'RU000A0ZYD22', 'sell_leg_seccode': '', 'trade_currency': 'SUR', 'second_currcode': '', 'face_value': 100.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': '', 'stock_code': '', 'sec_code': 'GTRK', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': '', 'class_name': 'МБ ФР: Неполные лоты', 'qty_multiplier': 1, 'list_level': 3, 'first_curr_qty_scale': 0, 'scale': 2, 'cusip_code': '', 'sell_mat_date': 0, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '1-01-84907-H', 'buybackdate': 0, 'buy_mat_date': 0, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'ПАО "ГТМ" ао', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'ГТМ ао', 'min_price_step': 0.05, 'buy_leg_seccode': '', 'code': 'GTRK', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'SMAL'}
# --- GTSS
# ...
# --- CHFRUB
# --- None
# --- TOD
# --- None
# --- CHFRUB
# --- None
# --- TOM
# --- None
# --- CNY
# --- None
# --- TOD
# --- None
# --- CNYRUBTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'CNY000000TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 100000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'CNYRUBTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 6, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'CNY_TODTOM - СВОП CNY/РУБ', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'CNY_TODTOM', 'min_price_step': 1e-06, 'buy_leg_seccode': 'CNYRUB_TOM', 'code': 'CNYRUBTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- CNYRUB
# --- None
# --- FWD
# --- None
# --- CNYRUB
# --- None
# --- SPT
# --- None
# --- CNYRUB
# --- None
# --- TOM
# --- None
# --- CNYRUB
# --- None
# --- TOM
# --- None
# --- D
# --- None
# --- CNYRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- CNYRUB
# --- None
# --- TOM
# --- None
# --- W
# --- None
# --- CNYRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- CNYRUB
# --- None
# --- TOM
# --- None
# --- W
# --- None
# --- CNYRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- CNYRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- EUR
# --- None
# --- TODTOM
# --- None
# --- EURRUB
# --- None
# --- FWD
# --- None
# --- EURRUB
# --- None
# --- SPT
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- D
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- W
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- Y
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- W
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- EURRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- EURUSD
# --- None
# --- TOD
# --- None
# --- EURUSD
# --- None
# --- TOM
# --- None
# --- EURUSDTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'EURUSD000TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 100000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'EURUSDTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 6, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'EUR/USD_TODTOM - СВОП EUR/USD', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'EURUSDTDTM', 'min_price_step': 1e-06, 'buy_leg_seccode': 'EURUSD000TOM', 'code': 'EURUSDTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- EURUSD
# --- None
# --- SPT
# --- None
# --- EURUSD
# --- None
# --- TOM
# --- None
# --- D
# --- None
# --- EUR
# --- None
# --- RUB
# --- None
# --- TOD
# --- None
# --- EUR
# --- None
# --- RUB
# --- None
# --- TOM
# --- None
# --- GBPRUBTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'GBPRUB_TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 100000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'GBPRUBTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'GBP_TODTOM - СВОП GBP/РУБ', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'GBP_TODTOM', 'min_price_step': 0.0001, 'buy_leg_seccode': 'GBPRUB_TOM', 'code': 'GBPRUBTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- GBPRUB
# --- None
# --- TOD
# --- None
# --- GBPRUB
# --- None
# --- TOM
# --- None
# --- GBPUSDTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'GBPUSD_TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 100000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'GBPUSDTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 6, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'GBP/USD_TODTOM - СВОП GBP/USD', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'GBPUSDTDTM', 'min_price_step': 1e-06, 'buy_leg_seccode': 'GBPUSD_TOM', 'code': 'GBPUSDTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- GBPUSD
# --- None
# --- SPT
# --- None
# --- GBPUSD
# --- None
# --- TOD
# --- None
# --- GBPUSD
# --- None
# --- TOM
# --- None
# --- GBPUSD
# --- None
# --- TOM
# --- None
# --- D
# --- None
# --- HKDRUBTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'HKDRUB_TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 100000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'HKDRUBTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 6, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'HKD_TODTOM - СВОП HKD/РУБ', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'HKD_TODTOM', 'min_price_step': 1e-06, 'buy_leg_seccode': 'HKDRUB_TOM', 'code': 'HKDRUBTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- HKDRUB
# --- None
# --- TOD
# --- None
# --- HKDRUB
# --- None
# --- TOM
# --- None
# --- JPYRUBTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'JPYRUB_TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 100.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1000000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'JPYRUBTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'JPY/RUB_TODTOM - СВОП JPY/РУБ', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'JPY_TODTOM', 'min_price_step': 0.0001, 'buy_leg_seccode': 'JPYRUB_TOM', 'code': 'JPYRUBTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- JPYRUB
# --- None
# --- TOD
# --- None
# --- JPYRUB
# --- None
# --- TOM
# --- None
# --- KZTRUBTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'KZTRUB_TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 100.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 1000000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'KZTRUBTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 4, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'KZT/RUB_TODTOM - СВОП KZT/РУБ', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'KZT_TODTOM', 'min_price_step': 0.0001, 'buy_leg_seccode': 'KZTRUB_TOM', 'code': 'KZTRUBTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- KZTRUB
# --- None
# --- FWD
# --- None
# --- KZTRUB
# --- None
# --- SPT
# --- None
# --- KZTRUB
# --- None
# --- TOD
# --- None
# --- KZTRUB
# --- None
# --- TOM
# --- None
# --- KZTRUB
# --- None
# --- TOM
# --- None
# --- D
# --- None
# --- KZTRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- KZTRUB
# --- None
# --- TOM
# --- None
# --- W
# --- None
# --- KZTRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- KZTRUB
# --- None
# --- TOM
# --- None
# --- W
# --- None
# --- KZTRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- KZTRUB
# --- None
# --- TOM
# --- None
# --- M
# --- None
# --- TRYRUBTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'TRYRUB_TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 100000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'TRYRUBTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 6, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'TRY_TODTOM - СВОП TRY/РУБ', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'TRY_TODTOM', 'min_price_step': 1e-06, 'buy_leg_seccode': 'TRYRUB_TOM', 'code': 'TRYRUBTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- TRYRUB
# --- None
# --- TOD
# --- None
# --- TRYRUB
# --- None
# --- TOM
# --- None
# --- UAH
# --- None
# --- TOM
# --- None
# --- USD
# --- None
# --- TOD
# --- None
# --- USD
# --- None
# --- TODTOM
# --- None
# --- USD
# --- None
# --- UTSTOM
# --- None
# --- USDCHFTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'USDCHF_TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 100000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'USDCHFTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 6, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'USD/CHF_TODTOM - СВОП USD/CHF', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'USDCHFTDTM', 'min_price_step': 1e-06, 'buy_leg_seccode': 'USDCHF_TOM', 'code': 'USDCHFTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- USDCHF
# --- None
# --- SPT
# --- None
# --- USDCHF
# --- None
# --- TOD
# --- None
# --- USDCHF
# --- None
# --- TOM
# --- None
# --- USDCHF
# --- None
# --- TOM
# --- None
# --- D
# --- None
# --- USDCNYTODTOM
# --- {'isin_code': '', 'sell_leg_seccode': 'USDCNY_TOD', 'trade_currency': '', 'second_currcode': '', 'face_value': 1.0, 'nextcoupon': 0, 'qty_scale': 0, 'step_price_currency': '', 'lot_size': 100000, 'face_unit': 'SUR', 'stock_name': '', 'ric_code': '', 'sell_leg_classcode': 'CETS', 'stock_code': '', 'sec_code': 'USDCNYTODTOM', 'bsid': '', 'base_active_seccode': '', 'buy_leg_classcode': 'CETS', 'class_name': 'МБ Валюта: ЕТС', 'qty_multiplier': 1, 'list_level': 0, 'first_curr_qty_scale': 0, 'scale': 6, 'cusip_code': '', 'sell_mat_date': 20210419, 'yieldatprevwaprice': 0.0, 'option_strike': 0.0, 'buybackprice': 0.0, 'regnumber': '', 'buybackdate': 0, 'buy_mat_date': 20210420, 'accruedint': 0.0, 'couponperiod': 0, 'name': 'USD/CNY_TODTOM - СВОП USD/CNY', 'cfi_code': '', 'second_curr_qty_scale': 0, 'first_currcode': '', 'couponvalue': 0.0, 'sedol_code': '', 'short_name': 'USDCNYTDTM', 'min_price_step': 1e-06, 'buy_leg_seccode': 'USDCNY_TOM', 'code': 'USDCNYTODTOM', 'base_active_classcode': '', 'mat_date': 0, 'class_code': 'CETS'}
# --- USDCNY
# --- None
# --- SPT
# --- None
# --- USDCNY
# --- None
# --- TOD
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# C:\Work\OneDrive - ООО «Кловер Групп»\work\Programs\QuikClient\src\quikclient\QuikClient.py in _get_cmd(self, cmd)
#      46             s.send(cmd_to_send.encode(self.unicode))
# ---> 47             number_chunk = json.loads(s.recv(32))
#      48             res = b''
#
# ~\anaconda3\envs\p38\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# ~\anaconda3\envs\p38\lib\json\decoder.py in decode(self, s, _w)
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#
# JSONDecodeError: Extra data: line 1 column 2 (char 1)
#
# The above exception was the direct cause of the following exception:
#
# ExceptionQuikClient                       Traceback (most recent call last)
# <ipython-input-14-a282358567c1> in <module>
#       5     for cod in codes:
#       6         print('---',cod)
# ----> 7         print('---', c.get_class_code_info(cls, cod))
#       8         # time.sleep(0.5)
#       9
#
# C:\Work\OneDrive - ООО «Кловер Групп»\work\Programs\QuikClient\src\quikclient\QuikClient.py in get_class_code_info(self, class_name, class_code)
#     106           'scale': 2, 'sec_code': 'GAZP', 'class_name': 'МБ ФР: Т+ Акции и ДР', 'first_currcode': ''}
#     107         """
# --> 108         return self._get_cmd('get_class_code_info("' + class_name + '","' + class_code + '")')
#     109
#     110     def get_candle_data(self, class_name: str, class_code: str, interval: str) -> pd.DataFrame:
#
# C:\Work\OneDrive - ООО «Кловер Групп»\work\Programs\QuikClient\src\quikclient\QuikClient.py in _get_cmd(self, cmd)
#      52             result = json.loads(res.decode(self.unicode))
#      53         except Exception as ex:
# ---> 54             raise ExceptionQuikClient('Ошибка соединения или передачи данных с QUIK') from ex
#      55         return result
#      56
#
# ExceptionQuikClient: Ошибка соединения или передачи данных с QUIK

# %%
c.get_class_codes_info('TQBR')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e0b4f9a3beae> in <module>
# ----> 1 c.get_class_codes_info('TQBR')
#       2
#
# AttributeError: 'QuikClient' object has no attribute 'get_class_codes_info'

# %%
c.get
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-5f2102521ec9> in <module>
# ----> 1 c.get
#
# AttributeError: 'QuikClient' object has no attribute 'get'

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
25
# Out:
# 25

# %%
65
# Out:
# 65
